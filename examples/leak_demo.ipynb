# %%
import pandas as pd

# %%
# This is a safe cell
df = pd.DataFrame({'a': range(100)})
rolling_mean = df.rolling(10).mean()

# %%
# This cell has a T001 violation
global_mean = df.mean()
print(global_mean)
